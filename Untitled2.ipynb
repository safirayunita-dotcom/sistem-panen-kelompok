# %% [markdown]
# <a href="https://colab.research.google.com/github/safirayunita-dotcom/sistem-panen-kelompok/blob/fitur-input/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/sistem-panen-kelompok
# !git status
# Out:
# [Errno 2] No such file or directory: '/content/sistem-panen-kelompok'
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git checkout -b fitur-input
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %%writefile input_panen.py

def input_data_panen():
    komoditas = input("Nama komoditas: ")
    jumlah_karung = int(input("Jumlah karung: "))
    berat_per_karung = float(input("Berat per karung (kg): "))

    return komoditas, jumlah_karung, berat_per_karung


komoditas, jumlah_karung, berat_per_karung = input_data_panen()

print("\n=== DATA PANEN ===")
print("Komoditas:", komoditas)
print("Jumlah karung:", jumlah_karung)
print("Berat per karung:", berat_per_karung, "kg")
# Out:
# Overwriting input_panen.py

# %%
# !python input_panen.py
# Out:
# Nama komoditas:

# %%
# !git status

# %%
# !git add .
# !git commit -m "Menambahkan fungsi input data panen"

# %%
# !git checkout main

# %%
# !git branch
